# %% [markdown]
# # Notebook- Preprocessing & Fit : ModelK13_2  Optimization Hyperas
# # Author : V.Albors   Date : 21.01.2020
# # Purpose : Optimization by Hyperas More layers, batch size
#
#
# **Input** :
#   * CSV files that identify the images to use as train and validation. CSV files are in directory csv_dir
#   * Images from train and validation. Images are in directory : imag_dir
#
#
# **Output**:
# * Optimize parameters :
#      * More layers
#      * Batch size
#
#
# **Process**:
#  * Read Train and Validation images ( identified in the .csv files ) from the imag_dir directory
#  * Create a model
#  * Compile Network
#  * Train the model to find best hyperparameters
#
#
# **To do hyper-parameter optimization on this model, just wrap the parameters you want to optimize into double curly brackets and choose a distribution over which to run the algorithm**

# %%
from __future__ import print_function
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

from keras.optimizers import Adam
# Do not write is do no want in choice 
from keras.optimizers import RMSprop
from keras.optimizers import SGD

#from keras.datasets import mnist
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.config.experimental.list_physical_devices('GPU') 
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  1

# %%
# Define the name of the model, directories & if to train the model 
Model_directory = "MODELN13"
Model_name = "ModelK13_2"
TRAIN = True

# %%
# Import routines
import sys  
subrc_dir = "/home/valborsf/Documents/UOC/PFMProject/"

sys.path.append(subrc_dir)  
from  Models_routines import *
import inspect

# List functions inside the module
import Models_routines as module
functions = inspect.getmembers(module, inspect.isfunction)
lsfunctions = [item[0] for item in functions]
print ( lsfunctions )
# Out:
# ['confusion_ROC_AUC', 'create_column_tensor', 'create_label_tensor', 'create_val_test', 'define_dirs', 'extract_images_bm', 'extract_images_train', 'load_hist_model', 'load_images', 'load_images_tf', 'model_load', 'plot_save_acc_loss', 'print_network', 'process_clinical_info', 'read_dataframes', 'read_dataframes_tables', 'reproducible_results', 'save_model', 'save_network_json', 'start', 'stop', 'to_one_hot', 'to_one_hot_words', 'xi_squared']

# %%
# Define directories
(root_dir,json_dir,imag_dir,csv_dir,model_json_dir,model_bin_dir,results_dir,Tensor_dir) = define_dirs(Model_directory)

# %%
def data():
        csv_dir =  root_dir +"/DataNew4/CSV/"   
        (dftrain, dfval, dftest) = read_dataframes(csv_dir)
        height_imag = 150 
        width_imag = 150
        x_train  = load_images_tf(dftrain,height_imag,width_imag)
        x_val    = load_images_tf(dfval,height_imag,width_imag)
        x_test   = load_images_tf(dftest,height_imag,width_imag)
        y_train  = create_label_tensor(dftrain)
        y_val    = create_label_tensor(dfval)
        y_test   = create_label_tensor(dftest)
        return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def create_model(x_train, y_train, x_val, y_val, x_test, y_test):
    import keras
    from hyperopt import Trials, STATUS_OK, tpe
    from keras import layers
    from keras import models
    from hyperas import optim
    from hyperas.distributions import choice, uniform
    import numpy as np
    from keras.utils import np_utils
    
    model = models.Sequential ()
    model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Conv2D(32, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Conv2D(128, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))
    num_layers = {{choice(['one', 'two'])}}
    if num_layers == 'two':
        model.add(layers.Conv2D({{choice([32, 64, 128])}}, (3,3), activation='relu'))
        model.add(layers.MaxPooling2D((2,2)))
 
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.23))  
    num_layers = {{choice(['three', 'four'])}}
    if num_layers == 'four':
        model.add(layers.Dense({{choice([32, 64, 128])}}, activation='relu'))

    model.add(layers.Dense(1, activation='sigmoid'))
    

    from keras import optimizers 
    from keras.optimizers import Adam
    
    adam = keras.optimizers.Adam(lr=1e-4)

    optim = adam
    
    
    model.compile ( loss='binary_crossentropy',
               optimizer = optim,
               metrics= ['acc'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=4)
    
    epochs = 100
    
    result = model.fit(x_train, y_train,
                      batch_size={{choice([64, 128])}},
                      epochs=100,
                      verbose=2,
                      validation_data=(x_val, y_val),
                      callbacks=[early_stopping])

    

    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
if __name__ == '__main__':
    import time

    start_time = time.time()
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          eval_space=True,
                                          notebook_name='ModelK13_Hyperas_21')
    x_train, y_train, x_val, y_val, x_test, y_test = data()

    print("Evalutation of best performing model:")
    print(best_model.evaluate(x_test, y_test))
    print("Best performing model chosen hyper-parameters:")
    print(best_run)
    
    elapsed_time = time.time() - start_time

    time.strftime('Time spent in TF loading :'"%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.optimizers import Adam
# except:
#     pass
#
# try:
#     from keras.optimizers import RMSprop
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     from Models_routines import *
# except:
#     pass
#
# try:
#     import inspect
# except:
#     pass
#
# try:
#     import Models_routines as module
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from keras import layers
# except:
#     pass
#
# try:
#     from keras import models
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras import optimizers
# except:
#     pass
#
# try:
#     from keras.optimizers import Adam
# except:
#     pass
#
# try:
#     import time
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'num_layers': hp.choice('num_layers', ['one', 'two']),
#         'Conv2D': hp.choice('Conv2D', [32, 64, 128]),
#         'num_layers_1': hp.choice('num_layers_1', ['three', 'four']),
#         'Conv2D_1': hp.choice('Conv2D_1', [32, 64, 128]),
#         'batch_size': hp.choice('batch_size', [64, 128]),
#     }
#
# >>> Data
#   1:
#   2: csv_dir =  root_dir +"/DataNew4/CSV/"
#   3: (dftrain, dfval, dftest) = read_dataframes(csv_dir)
#   4: height_imag = 150
#   5: width_imag = 150
#   6: x_train  = load_images_tf(dftrain,height_imag,width_imag)
#   7: x_val    = load_images_tf(dfval,height_imag,width_imag)
#   8: x_test   = load_images_tf(dftest,height_imag,width_imag)
#   9: y_train  = create_label_tensor(dftrain)
#  10: y_val    = create_label_tensor(dfval)
#  11: y_test   = create_label_tensor(dftest)
#  12:
#  13:
#  14:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = models.Sequential ()
#    5:     model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)))
#    6:     model.add(layers.MaxPooling2D((2,2)))
#    7:     model.add(layers.Conv2D(32, (3,3), activation='relu'))
#    8:     model.add(layers.MaxPooling2D((2,2)))
#    9:     model.add(layers.Conv2D(128, (3,3), activation='relu'))
#   10:     model.add(layers.MaxPooling2D((2,2)))
#   11:     num_layers = space['num_layers']
#   12:     if num_layers == 'two':
#   13:         model.add(layers.Conv2D(space['Conv2D'], (3,3), activation='relu'))
#   14:         model.add(layers.MaxPooling2D((2,2)))
#   15:
#   16:     model.add(layers.Flatten())
#   17:     model.add(layers.Dense(512, activation='relu'))
#   18:     model.add(layers.Dropout(0.23))
#   19:     num_layers = space['num_layers_1']
#   20:     if num_layers == 'four':
#   21:         model.add(layers.Dense(space['Conv2D_1'], activation='relu'))
#   22:
#   23:     model.add(layers.Dense(1, activation='sigmoid'))
#   24:
#   25:
#   26:
#   27:     adam = keras.optimizers.Adam(lr=1e-4)
#   28:
#   29:     optim = adam
#   30:
#   31:
#   32:     model.compile ( loss='binary_crossentropy',
#   33:                optimizer = optim,
#   34:                metrics= ['acc'])
#   35:     early_stopping = EarlyStopping(monitor='val_loss', patience=4)
#   36:
#   37:     epochs = 100
#   38:
#   39:     result = model.fit(x_train, y_train,
#   40:                       batch_size=space['batch_size'],
#   41:                       epochs=100,
#   42:                       verbose=2,
#   43:                       validation_data=(x_val, y_val),
#   44:                       callbacks=[early_stopping])
#   45:
#   46:
#   47:
#   48:     validation_acc = np.amax(result.history['val_acc'])
#   49:     print('Best validation acc of epoch:', validation_acc)
#   50:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   51:
# /home/valborsf/Documents/UOC/PFMProject/DataNew4/CSV/
# Executing op ReadFile in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DecodeJpeg in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ExpandDims in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ResizeBilinear in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Squeeze in device /job:localhost/replica:0/task:0/device:CPU:0
# (2100, 150, 150, 3)
# (700, 150, 150, 3)
# (700, 150, 150, 3)
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_40351 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_40459 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 5s - loss: 0.6905 - acc: 0.5200 - val_loss: 0.6822 - val_acc: 0.5471
#
# Epoch 2/100
#  - 2s - loss: 0.6756 - acc: 0.5833 - val_loss: 0.6448 - val_acc: 0.6714
#
# Epoch 3/100
#  - 2s - loss: 0.6340 - acc: 0.6300 - val_loss: 0.6634 - val_acc: 0.6386
#
# Epoch 4/100
#  - 2s - loss: 0.6195 - acc: 0.6400 - val_loss: 0.6361 - val_acc: 0.5686
#
# Epoch 5/100
#  - 2s - loss: 0.5920 - acc: 0.6619 - val_loss: 0.5543 - val_acc: 0.7000
#
# Epoch 6/100
#  - 2s - loss: 0.5696 - acc: 0.6833 - val_loss: 0.5475 - val_acc: 0.7271
#
# Epoch 7/100
#  - 2s - loss: 0.5694 - acc: 0.6881 - val_loss: 0.5696 - val_acc: 0.6771
#
# Epoch 8/100
#  - 2s - loss: 0.5571 - acc: 0.6976 - val_loss: 0.5873 - val_acc: 0.6743
#
# Epoch 9/100
#  - 2s - loss: 0.5461 - acc: 0.7090 - val_loss: 0.5294 - val_acc: 0.7300
#
# Epoch 10/100
#  - 2s - loss: 0.5380 - acc: 0.7176 - val_loss: 0.5566 - val_acc: 0.7000
#
# Epoch 11/100
#  - 2s - loss: 0.5540 - acc: 0.7000 - val_loss: 0.5118 - val_acc: 0.7514
#
# Epoch 12/100
#  - 2s - loss: 0.5235 - acc: 0.7195 - val_loss: 0.5018 - val_acc: 0.7386
#
# Epoch 13/100
#  - 2s - loss: 0.5166 - acc: 0.7210 - val_loss: 0.5393 - val_acc: 0.7071
#
# Epoch 14/100
#  - 2s - loss: 0.5451 - acc: 0.6890 - val_loss: 0.5107 - val_acc: 0.7457
#
# Epoch 15/100
#  - 2s - loss: 0.5150 - acc: 0.7167 - val_loss: 0.4945 - val_acc: 0.7400
#
# Epoch 16/100
#  - 2s - loss: 0.5125 - acc: 0.7138 - val_loss: 0.5036 - val_acc: 0.7400
#
# Epoch 17/100
#  - 2s - loss: 0.5080 - acc: 0.7186 - val_loss: 0.5119 - val_acc: 0.7400
#
# Epoch 18/100
#  - 2s - loss: 0.5025 - acc: 0.7281 - val_loss: 0.4901 - val_acc: 0.7557
#
# Epoch 19/100
#  - 2s - loss: 0.5077 - acc: 0.7295 - val_loss: 0.5217 - val_acc: 0.7143
#
# Epoch 20/100
#  - 2s - loss: 0.5088 - acc: 0.7257 - val_loss: 0.4947 - val_acc: 0.7443
#
# Epoch 21/100
#  - 2s - loss: 0.4990 - acc: 0.7386 - val_loss: 0.4933 - val_acc: 0.7514
#
# Epoch 22/100
#  - 2s - loss: 0.4929 - acc: 0.7357 - val_loss: 0.4991 - val_acc: 0.7471
#
# Best validation acc of epoch:
# 0.7557142972946167
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_47976 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_48076 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 4s - loss: 0.6950 - acc: 0.5343 - val_loss: 0.6755 - val_acc: 0.6229
#
# Epoch 2/100
#  - 2s - loss: 0.6666 - acc: 0.5957 - val_loss: 0.6392 - val_acc: 0.6743
#
# Epoch 3/100
#  - 2s - loss: 0.6338 - acc: 0.6419 - val_loss: 0.6026 - val_acc: 0.6600
#
# Epoch 4/100
#  - 2s - loss: 0.5955 - acc: 0.6610 - val_loss: 0.5740 - val_acc: 0.6814
#
# Epoch 5/100
#  - 2s - loss: 0.5729 - acc: 0.6919 - val_loss: 0.5886 - val_acc: 0.6900
#
# Epoch 6/100
#  - 2s - loss: 0.5750 - acc: 0.6743 - val_loss: 0.5453 - val_acc: 0.7071
#
# Epoch 7/100
#  - 2s - loss: 0.5627 - acc: 0.6814 - val_loss: 0.5351 - val_acc: 0.7443
#
# Epoch 8/100
#  - 2s - loss: 0.5506 - acc: 0.6976 - val_loss: 0.5357 - val_acc: 0.7443
#
# Epoch 9/100
#  - 2s - loss: 0.5402 - acc: 0.7071 - val_loss: 0.5287 - val_acc: 0.7071
#
# Epoch 10/100
#  - 2s - loss: 0.5209 - acc: 0.7229 - val_loss: 0.5174 - val_acc: 0.7529
#
# Epoch 11/100
#  - 2s - loss: 0.5280 - acc: 0.7190 - val_loss: 0.5045 - val_acc: 0.7486
#
# Epoch 12/100
#  - 2s - loss: 0.5160 - acc: 0.7181 - val_loss: 0.5081 - val_acc: 0.7443
#
# Epoch 13/100
#  - 2s - loss: 0.5052 - acc: 0.7381 - val_loss: 0.5102 - val_acc: 0.7614
#
# Epoch 14/100
#  - 2s - loss: 0.5094 - acc: 0.7338 - val_loss: 0.4939 - val_acc: 0.7671
#
# Epoch 15/100
#  - 2s - loss: 0.4931 - acc: 0.7405 - val_loss: 0.5014 - val_acc: 0.7429
#
# Epoch 16/100
#  - 2s - loss: 0.4939 - acc: 0.7410 - val_loss: 0.5328 - val_acc: 0.7329
#
# Epoch 17/100
#  - 2s - loss: 0.5042 - acc: 0.7348 - val_loss: 0.4904 - val_acc: 0.7514
#
# Epoch 18/100
#  - 2s - loss: 0.4887 - acc: 0.7486 - val_loss: 0.4935 - val_acc: 0.7571
#
# Epoch 19/100
#  - 2s - loss: 0.4823 - acc: 0.7443 - val_loss: 0.4790 - val_acc: 0.7629
#
# Epoch 20/100
#  - 2s - loss: 0.4727 - acc: 0.7562 - val_loss: 0.4795 - val_acc: 0.7600
#
# Epoch 21/100
#  - 2s - loss: 0.4693 - acc: 0.7567 - val_loss: 0.5279 - val_acc: 0.7129
#
# Epoch 22/100
#  - 2s - loss: 0.4783 - acc: 0.7495 - val_loss: 0.4856 - val_acc: 0.7429
#
# Epoch 23/100
#  - 2s - loss: 0.4668 - acc: 0.7581 - val_loss: 0.4789 - val_acc: 0.7643
#
# Epoch 24/100
#  - 2s - loss: 0.4645 - acc: 0.7662 - val_loss: 0.5122 - val_acc: 0.7429
#
# Epoch 25/100
#  - 2s - loss: 0.4648 - acc: 0.7662 - val_loss: 0.5096 - val_acc: 0.7214
#
# Epoch 26/100
#  - 2s - loss: 0.4522 - acc: 0.7648 - val_loss: 0.4918 - val_acc: 0.7614
#
# Epoch 27/100
#  - 2s - loss: 0.4551 - acc: 0.7686 - val_loss: 0.5026 - val_acc: 0.7386
#
# Best validation acc of epoch:
# 0.7671428322792053
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_53749 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_53856 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 3s - loss: 0.6958 - acc: 0.5343 - val_loss: 0.6786 - val_acc: 0.6471
#
# Epoch 2/100
#  - 2s - loss: 0.6748 - acc: 0.5695 - val_loss: 0.6509 - val_acc: 0.6657
#
# Epoch 3/100
#  - 2s - loss: 0.6462 - acc: 0.6129 - val_loss: 0.6077 - val_acc: 0.6786
#
# Epoch 4/100
#  - 2s - loss: 0.6064 - acc: 0.6514 - val_loss: 0.5745 - val_acc: 0.7029
#
# Epoch 5/100
#  - 2s - loss: 0.5845 - acc: 0.6848 - val_loss: 0.5555 - val_acc: 0.6957
#
# Epoch 6/100
#  - 2s - loss: 0.5661 - acc: 0.6848 - val_loss: 0.5485 - val_acc: 0.7429
#
# Epoch 7/100
#  - 2s - loss: 0.5591 - acc: 0.6929 - val_loss: 0.5281 - val_acc: 0.7314
#
# Epoch 8/100
#  - 2s - loss: 0.5522 - acc: 0.7005 - val_loss: 0.5405 - val_acc: 0.7200
#
# Epoch 9/100
#  - 2s - loss: 0.5362 - acc: 0.7033 - val_loss: 0.5218 - val_acc: 0.7443
#
# Epoch 10/100
#  - 2s - loss: 0.5550 - acc: 0.6924 - val_loss: 0.5603 - val_acc: 0.6443
#
# Epoch 11/100
#  - 2s - loss: 0.5296 - acc: 0.7105 - val_loss: 0.5029 - val_acc: 0.7543
#
# Epoch 12/100
#  - 2s - loss: 0.5132 - acc: 0.7224 - val_loss: 0.5059 - val_acc: 0.7371
#
# Epoch 13/100
#  - 2s - loss: 0.5068 - acc: 0.7262 - val_loss: 0.5008 - val_acc: 0.7300
#
# Epoch 14/100
#  - 2s - loss: 0.4989 - acc: 0.7333 - val_loss: 0.5014 - val_acc: 0.7300
#
# Epoch 15/100
#  - 2s - loss: 0.4982 - acc: 0.7386 - val_loss: 0.4963 - val_acc: 0.7400
#
# Epoch 16/100
#  - 2s - loss: 0.4944 - acc: 0.7286 - val_loss: 0.5354 - val_acc: 0.7286
#
# Epoch 17/100
#  - 2s - loss: 0.4960 - acc: 0.7410 - val_loss: 0.5108 - val_acc: 0.7414
#
# Epoch 18/100
#  - 2s - loss: 0.4916 - acc: 0.7571 - val_loss: 0.4985 - val_acc: 0.7414
#
# Epoch 19/100
#  - 2s - loss: 0.4796 - acc: 0.7424 - val_loss: 0.4832 - val_acc: 0.7529
#
# Epoch 20/100
#  - 2s - loss: 0.4732 - acc: 0.7529 - val_loss: 0.5012 - val_acc: 0.7457
#
# Epoch 21/100
#  - 2s - loss: 0.4676 - acc: 0.7633 - val_loss: 0.4870 - val_acc: 0.7329
#
# Epoch 22/100
#  - 2s - loss: 0.4720 - acc: 0.7552 - val_loss: 0.4953 - val_acc: 0.7386
#
# Epoch 23/100
#  - 2s - loss: 0.4512 - acc: 0.7657 - val_loss: 0.4832 - val_acc: 0.7486
#
# Best validation acc of epoch:
# 0.7542856931686401
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_62085 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_62200 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 2s - loss: 0.6901 - acc: 0.5538 - val_loss: 0.6839 - val_acc: 0.6100
#
# Epoch 2/100
#  - 2s - loss: 0.6800 - acc: 0.6029 - val_loss: 0.6660 - val_acc: 0.6900
#
# Epoch 3/100
#  - 2s - loss: 0.6567 - acc: 0.6271 - val_loss: 0.6624 - val_acc: 0.5529
#
# Epoch 4/100
#  - 2s - loss: 0.6274 - acc: 0.6433 - val_loss: 0.6071 - val_acc: 0.7000
#
# Epoch 5/100
#  - 2s - loss: 0.6085 - acc: 0.6629 - val_loss: 0.5776 - val_acc: 0.6900
#
# Epoch 6/100
#  - 2s - loss: 0.5944 - acc: 0.6662 - val_loss: 0.5808 - val_acc: 0.7029
#
# Epoch 7/100
#  - 2s - loss: 0.6121 - acc: 0.6629 - val_loss: 0.6550 - val_acc: 0.5943
#
# Epoch 8/100
#  - 2s - loss: 0.6401 - acc: 0.6233 - val_loss: 0.6062 - val_acc: 0.6914
#
# Epoch 9/100
#  - 2s - loss: 0.5917 - acc: 0.6681 - val_loss: 0.5613 - val_acc: 0.7143
#
# Epoch 10/100
#  - 2s - loss: 0.5643 - acc: 0.7014 - val_loss: 0.5554 - val_acc: 0.6914
#
# Epoch 11/100
#  - 2s - loss: 0.5595 - acc: 0.6981 - val_loss: 0.5297 - val_acc: 0.7529
#
# Epoch 12/100
#  - 2s - loss: 0.5517 - acc: 0.7086 - val_loss: 0.5196 - val_acc: 0.7500
#
# Epoch 13/100
#  - 2s - loss: 0.5874 - acc: 0.6776 - val_loss: 0.5490 - val_acc: 0.7157
#
# Epoch 14/100
#  - 2s - loss: 0.5611 - acc: 0.6933 - val_loss: 0.5183 - val_acc: 0.7586
#
# Epoch 15/100
#  - 2s - loss: 0.5529 - acc: 0.7019 - val_loss: 0.5117 - val_acc: 0.7600
#
# Epoch 16/100
#  - 2s - loss: 0.5357 - acc: 0.7157 - val_loss: 0.5054 - val_acc: 0.7557
#
# Epoch 17/100
#  - 2s - loss: 0.5278 - acc: 0.7205 - val_loss: 0.5790 - val_acc: 0.6814
#
# Epoch 18/100
#  - 2s - loss: 0.5396 - acc: 0.7090 - val_loss: 0.5928 - val_acc: 0.6486
#
# Epoch 19/100
#  - 2s - loss: 0.5272 - acc: 0.7195 - val_loss: 0.5087 - val_acc: 0.7429
#
# Epoch 20/100
#  - 2s - loss: 0.5432 - acc: 0.7043 - val_loss: 0.5240 - val_acc: 0.7300
#
# Best validation acc of epoch:
# 0.7599999904632568
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_66879 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_66986 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 2s - loss: 0.6906 - acc: 0.5300 - val_loss: 0.6756 - val_acc: 0.5371
#
# Epoch 2/100
#  - 2s - loss: 0.6697 - acc: 0.5852 - val_loss: 0.6424 - val_acc: 0.6200
#
# Epoch 3/100
#  - 2s - loss: 0.6425 - acc: 0.6133 - val_loss: 0.6360 - val_acc: 0.5557
#
# Epoch 4/100
#  - 2s - loss: 0.6223 - acc: 0.6410 - val_loss: 0.5825 - val_acc: 0.6714
#
# Epoch 5/100
#  - 2s - loss: 0.5966 - acc: 0.6624 - val_loss: 0.5661 - val_acc: 0.6900
#
# Epoch 6/100
#  - 2s - loss: 0.5780 - acc: 0.6848 - val_loss: 0.5721 - val_acc: 0.6743
#
# Epoch 7/100
#  - 2s - loss: 0.5663 - acc: 0.6938 - val_loss: 0.5511 - val_acc: 0.6971
#
# Epoch 8/100
#  - 2s - loss: 0.5685 - acc: 0.6981 - val_loss: 0.5356 - val_acc: 0.6929
#
# Epoch 9/100
#  - 2s - loss: 0.5475 - acc: 0.7071 - val_loss: 0.5266 - val_acc: 0.7114
#
# Epoch 10/100
#  - 2s - loss: 0.5381 - acc: 0.7067 - val_loss: 0.5150 - val_acc: 0.7329
#
# Epoch 11/100
#  - 2s - loss: 0.5231 - acc: 0.7119 - val_loss: 0.5024 - val_acc: 0.7457
#
# Epoch 12/100
#  - 2s - loss: 0.5139 - acc: 0.7310 - val_loss: 0.4943 - val_acc: 0.7443
#
# Epoch 13/100
#  - 2s - loss: 0.5031 - acc: 0.7290 - val_loss: 0.4990 - val_acc: 0.7500
#
# Epoch 14/100
#  - 2s - loss: 0.5003 - acc: 0.7362 - val_loss: 0.5011 - val_acc: 0.7300
#
# Epoch 15/100
#  - 2s - loss: 0.4988 - acc: 0.7338 - val_loss: 0.4862 - val_acc: 0.7357
#
# Epoch 16/100
#  - 2s - loss: 0.4971 - acc: 0.7376 - val_loss: 0.4848 - val_acc: 0.7257
#
# Epoch 17/100
#  - 2s - loss: 0.4863 - acc: 0.7448 - val_loss: 0.4779 - val_acc: 0.7514
#
# Epoch 18/100
#  - 2s - loss: 0.4762 - acc: 0.7576 - val_loss: 0.5055 - val_acc: 0.7200
#
# Epoch 19/100
#  - 2s - loss: 0.4792 - acc: 0.7643 - val_loss: 0.4790 - val_acc: 0.7586
#
# Epoch 20/100
#  - 2s - loss: 0.4692 - acc: 0.7581 - val_loss: 0.4788 - val_acc: 0.7471
#
# Epoch 21/100
#  - 2s - loss: 0.4745 - acc: 0.7519 - val_loss: 0.5006 - val_acc: 0.7343
#
# Best validation acc of epoch:
# 0.758571445941925
# 100%|██████████| 5/5 [04:18<00:00, 51.62s/it, best loss: -0.7671428322792053]
# /home/valborsf/Documents/UOC/PFMProject/DataNew4/CSV/
# (2100, 150, 150, 3)
# (700, 150, 150, 3)
# (700, 150, 150, 3)
# Evalutation of best performing model:
# 700/700 [==============================] - 1s 954us/step
# [0.49633056691714694, 0.7342857122421265]
# Best performing model chosen hyper-parameters:
# {'Conv2D': 128, 'Conv2D_1': 32, 'batch_size': 128, 'num_layers': 'one', 'num_layers_1': 'three'}

# %%
print(time.strftime('Time spent in TF loading :'"%H:%M:%S", time.gmtime(elapsed_time)))

# %%
# Results :
#Dense 64
#Batch size 64
#num_layers one
