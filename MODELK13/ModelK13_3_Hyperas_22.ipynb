# %% [markdown]
# # Notebook- Preprocessing & Fit : ModelK13_3  Optimization Hyperas
# # Author : V.Albors   Date : 21.01.2020
# # Purpose : Optimization by Hyperas Size of last dense layer
#
#
# **Input** :
#   * CSV files that identify the images to use as train and validation. CSV files are in directory csv_dir
#   * Images from train and validation. Images are in directory : imag_dir
#
#
# **Output**:
# * Optimize parameters :
#      * Size of the last dense layer
#
#
# **Process**:
#  * Read Train and Validation images ( identified in the .csv files ) from the imag_dir directory
#  * Create a model
#  * Compile Network
#  * Train the model to find best hyperparameters
#
#
# **To do hyper-parameter optimization on this model, just wrap the parameters you want to optimize into double curly brackets and choose a distribution over which to run the algorithm**

# %%
from __future__ import print_function
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

from keras.optimizers import Adam
# Do not write is do no want in choice 
from keras.optimizers import RMSprop
from keras.optimizers import SGD

#from keras.datasets import mnist
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.config.experimental.list_physical_devices('GPU') 
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  1

# %%
# Define the name of the model, directories & if to train the model 
Model_directory = "MODELN13"
Model_name = "ModelK13_3"
TRAIN = True

# %%
# Import routines
import sys  
subrc_dir = "/home/valborsf/Documents/UOC/PFMProject/"

sys.path.append(subrc_dir)  
from  Models_routines import *
import inspect

# List functions inside the module
import Models_routines as module
functions = inspect.getmembers(module, inspect.isfunction)
lsfunctions = [item[0] for item in functions]
print ( lsfunctions )
# Out:
# ['confusion_ROC_AUC', 'create_column_tensor', 'create_label_tensor', 'create_val_test', 'define_dirs', 'extract_images_bm', 'extract_images_train', 'load_hist_model', 'load_images', 'load_images_tf', 'model_load', 'plot_save_acc_loss', 'print_network', 'process_clinical_info', 'read_dataframes', 'read_dataframes_tables', 'reproducible_results', 'save_model', 'save_network_json', 'start', 'stop', 'to_one_hot', 'to_one_hot_words', 'xi_squared']

# %%
# Define directories
(root_dir,json_dir,imag_dir,csv_dir,model_json_dir,model_bin_dir,results_dir,Tensor_dir) = define_dirs(Model_directory)

# %%
def data():
        csv_dir =  root_dir +"/DataNew4/CSV/"   
        (dftrain, dfval, dftest) = read_dataframes(csv_dir)
        height_imag = 150 
        width_imag = 150
        x_train  = load_images_tf(dftrain,height_imag,width_imag)
        x_val    = load_images_tf(dfval,height_imag,width_imag)
        x_test   = load_images_tf(dftest,height_imag,width_imag)
        y_train  = create_label_tensor(dftrain)
        y_val    = create_label_tensor(dfval)
        y_test   = create_label_tensor(dftest)
        return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def create_model(x_train, y_train, x_val, y_val, x_test, y_test):
    import keras
    from hyperopt import Trials, STATUS_OK, tpe
    from keras import layers
    from keras import models
    from hyperas import optim
    from hyperas.distributions import choice, uniform
    import numpy as np
    from keras.utils import np_utils
    
    model = models.Sequential ()
    model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Conv2D(32, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Conv2D(128, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))
 
    model.add(layers.Flatten())
    model.add(layers.Dense({{choice([64, 128, 512])}}, activation='relu'))
    model.add(layers.Dropout(0.23))  
    

    model.add(layers.Dense(1, activation='sigmoid'))
    

    from keras import optimizers 
    from keras.optimizers import Adam
    
    adam = keras.optimizers.Adam(lr=1e-4)

    optim = adam
    
    
    model.compile ( loss='binary_crossentropy',
               optimizer = optim,
               metrics= ['acc'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=4)
    
    epochs = 100
    
    result = model.fit(x_train, y_train,
                      batch_size={{choice([64, 128])}},
                      epochs=100,
                      verbose=2,
                      validation_data=(x_val, y_val),
                      callbacks=[early_stopping])

    

    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
if __name__ == '__main__':
    import time

    start_time = time.time()
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          eval_space=True,
                                          notebook_name='ModelK13_Hyperas_22')
    x_train, y_train, x_val, y_val, x_test, y_test = data()

    print("Evalutation of best performing model:")
    print(best_model.evaluate(x_test, y_test))
    print("Best performing model chosen hyper-parameters:")
    print(best_run)
    
    elapsed_time = time.time() - start_time

    time.strftime('Time spent in TF loading :'"%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.optimizers import Adam
# except:
#     pass
#
# try:
#     from keras.optimizers import RMSprop
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     from Models_routines import *
# except:
#     pass
#
# try:
#     import inspect
# except:
#     pass
#
# try:
#     import Models_routines as module
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from keras import layers
# except:
#     pass
#
# try:
#     from keras import models
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras import optimizers
# except:
#     pass
#
# try:
#     from keras.optimizers import Adam
# except:
#     pass
#
# try:
#     import time
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [64, 128, 512]),
#         'batch_size': hp.choice('batch_size', [64, 128]),
#     }
#
# >>> Data
#   1:
#   2: csv_dir =  root_dir +"/DataNew4/CSV/"
#   3: (dftrain, dfval, dftest) = read_dataframes(csv_dir)
#   4: height_imag = 150
#   5: width_imag = 150
#   6: x_train  = load_images_tf(dftrain,height_imag,width_imag)
#   7: x_val    = load_images_tf(dfval,height_imag,width_imag)
#   8: x_test   = load_images_tf(dftest,height_imag,width_imag)
#   9: y_train  = create_label_tensor(dftrain)
#  10: y_val    = create_label_tensor(dfval)
#  11: y_test   = create_label_tensor(dftest)
#  12:
#  13:
#  14:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = models.Sequential ()
#    5:     model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)))
#    6:     model.add(layers.MaxPooling2D((2,2)))
#    7:     model.add(layers.Conv2D(32, (3,3), activation='relu'))
#    8:     model.add(layers.MaxPooling2D((2,2)))
#    9:     model.add(layers.Conv2D(128, (3,3), activation='relu'))
#   10:     model.add(layers.MaxPooling2D((2,2)))
#   11:
#   12:     model.add(layers.Flatten())
#   13:     model.add(layers.Dense(space['Dense'], activation='relu'))
#   14:     model.add(layers.Dropout(0.23))
#   15:
#   16:
#   17:     model.add(layers.Dense(1, activation='sigmoid'))
#   18:
#   19:
#   20:
#   21:     adam = keras.optimizers.Adam(lr=1e-4)
#   22:
#   23:     optim = adam
#   24:
#   25:
#   26:     model.compile ( loss='binary_crossentropy',
#   27:                optimizer = optim,
#   28:                metrics= ['acc'])
#   29:     early_stopping = EarlyStopping(monitor='val_loss', patience=4)
#   30:
#   31:     epochs = 100
#   32:
#   33:     result = model.fit(x_train, y_train,
#   34:                       batch_size=space['batch_size'],
#   35:                       epochs=100,
#   36:                       verbose=2,
#   37:                       validation_data=(x_val, y_val),
#   38:                       callbacks=[early_stopping])
#   39:
#   40:
#   41:
#   42:     validation_acc = np.amax(result.history['val_acc'])
#   43:     print('Best validation acc of epoch:', validation_acc)
#   44:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   45:
# /home/valborsf/Documents/UOC/PFMProject/DataNew4/CSV/
# Executing op ReadFile in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DecodeJpeg in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ExpandDims in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ResizeBilinear in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Squeeze in device /job:localhost/replica:0/task:0/device:CPU:0
# (2100, 150, 150, 3)
# (700, 150, 150, 3)
# (700, 150, 150, 3)
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_40125 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_40225 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 5s - loss: 0.6942 - acc: 0.5271 - val_loss: 0.6830 - val_acc: 0.6300
#
# Epoch 2/100
#  - 2s - loss: 0.6664 - acc: 0.6171 - val_loss: 0.6378 - val_acc: 0.6671
#
# Epoch 3/100
#  - 2s - loss: 0.6308 - acc: 0.6405 - val_loss: 0.6297 - val_acc: 0.5814
#
# Epoch 4/100
#  - 2s - loss: 0.6126 - acc: 0.6486 - val_loss: 0.5939 - val_acc: 0.6729
#
# Epoch 5/100
#  - 2s - loss: 0.5946 - acc: 0.6762 - val_loss: 0.5893 - val_acc: 0.6500
#
# Epoch 6/100
#  - 2s - loss: 0.5791 - acc: 0.6933 - val_loss: 0.5768 - val_acc: 0.6614
#
# Epoch 7/100
#  - 2s - loss: 0.5963 - acc: 0.6619 - val_loss: 0.5657 - val_acc: 0.7171
#
# Epoch 8/100
#  - 2s - loss: 0.5685 - acc: 0.6905 - val_loss: 0.5524 - val_acc: 0.7157
#
# Epoch 9/100
#  - 2s - loss: 0.5514 - acc: 0.7048 - val_loss: 0.5451 - val_acc: 0.7129
#
# Epoch 10/100
#  - 2s - loss: 0.5523 - acc: 0.6914 - val_loss: 0.5451 - val_acc: 0.7057
#
# Epoch 11/100
#  - 2s - loss: 0.5378 - acc: 0.7157 - val_loss: 0.5672 - val_acc: 0.7171
#
# Epoch 12/100
#  - 2s - loss: 0.5475 - acc: 0.7090 - val_loss: 0.5424 - val_acc: 0.7014
#
# Epoch 13/100
#  - 2s - loss: 0.5298 - acc: 0.7148 - val_loss: 0.5361 - val_acc: 0.6914
#
# Epoch 14/100
#  - 2s - loss: 0.5340 - acc: 0.7086 - val_loss: 0.5432 - val_acc: 0.6743
#
# Epoch 15/100
#  - 2s - loss: 0.5189 - acc: 0.7252 - val_loss: 0.5261 - val_acc: 0.7043
#
# Epoch 16/100
#  - 2s - loss: 0.5091 - acc: 0.7343 - val_loss: 0.5193 - val_acc: 0.6957
#
# Epoch 17/100
#  - 2s - loss: 0.5137 - acc: 0.7210 - val_loss: 0.5000 - val_acc: 0.7429
#
# Epoch 18/100
#  - 2s - loss: 0.5071 - acc: 0.7286 - val_loss: 0.4917 - val_acc: 0.7514
#
# Epoch 19/100
#  - 2s - loss: 0.4943 - acc: 0.7405 - val_loss: 0.5281 - val_acc: 0.6757
#
# Epoch 20/100
#  - 2s - loss: 0.4919 - acc: 0.7376 - val_loss: 0.5346 - val_acc: 0.7186
#
# Epoch 21/100
#  - 2s - loss: 0.4960 - acc: 0.7386 - val_loss: 0.4844 - val_acc: 0.7586
#
# Epoch 22/100
#  - 2s - loss: 0.5003 - acc: 0.7376 - val_loss: 0.5119 - val_acc: 0.7471
#
# Epoch 23/100
#  - 2s - loss: 0.4873 - acc: 0.7490 - val_loss: 0.4984 - val_acc: 0.7543
#
# Epoch 24/100
#  - 2s - loss: 0.4895 - acc: 0.7376 - val_loss: 0.4861 - val_acc: 0.7571
#
# Epoch 25/100
#  - 2s - loss: 0.4833 - acc: 0.7443 - val_loss: 0.4937 - val_acc: 0.7471
#
# Best validation acc of epoch:
# 0.758571445941925
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_48546 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_48646 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 3s - loss: 0.7107 - acc: 0.5152 - val_loss: 0.6743 - val_acc: 0.5414
#
# Epoch 2/100
#  - 2s - loss: 0.6670 - acc: 0.5857 - val_loss: 0.6482 - val_acc: 0.6814
#
# Epoch 3/100
#  - 2s - loss: 0.6387 - acc: 0.6214 - val_loss: 0.6015 - val_acc: 0.6786
#
# Epoch 4/100
#  - 2s - loss: 0.6137 - acc: 0.6538 - val_loss: 0.5774 - val_acc: 0.6900
#
# Epoch 5/100
#  - 2s - loss: 0.5784 - acc: 0.6919 - val_loss: 0.5529 - val_acc: 0.7329
#
# Epoch 6/100
#  - 2s - loss: 0.5953 - acc: 0.6590 - val_loss: 0.5496 - val_acc: 0.7200
#
# Epoch 7/100
#  - 2s - loss: 0.5593 - acc: 0.7005 - val_loss: 0.5529 - val_acc: 0.7343
#
# Epoch 8/100
#  - 2s - loss: 0.5485 - acc: 0.7067 - val_loss: 0.5232 - val_acc: 0.7614
#
# Epoch 9/100
#  - 2s - loss: 0.5383 - acc: 0.7100 - val_loss: 0.5281 - val_acc: 0.7086
#
# Epoch 10/100
#  - 2s - loss: 0.5384 - acc: 0.7105 - val_loss: 0.5234 - val_acc: 0.7486
#
# Epoch 11/100
#  - 2s - loss: 0.5213 - acc: 0.7152 - val_loss: 0.5055 - val_acc: 0.7557
#
# Epoch 12/100
#  - 2s - loss: 0.5229 - acc: 0.7095 - val_loss: 0.4986 - val_acc: 0.7586
#
# Epoch 13/100
#  - 2s - loss: 0.5040 - acc: 0.7338 - val_loss: 0.4965 - val_acc: 0.7443
#
# Epoch 14/100
#  - 2s - loss: 0.4986 - acc: 0.7329 - val_loss: 0.4956 - val_acc: 0.7500
#
# Epoch 15/100
#  - 2s - loss: 0.5000 - acc: 0.7324 - val_loss: 0.4940 - val_acc: 0.7557
#
# Epoch 16/100
#  - 2s - loss: 0.4847 - acc: 0.7600 - val_loss: 0.4977 - val_acc: 0.7371
#
# Epoch 17/100
#  - 2s - loss: 0.4839 - acc: 0.7429 - val_loss: 0.5344 - val_acc: 0.7100
#
# Epoch 18/100
#  - 2s - loss: 0.4739 - acc: 0.7500 - val_loss: 0.4808 - val_acc: 0.7629
#
# Epoch 19/100
#  - 2s - loss: 0.4681 - acc: 0.7538 - val_loss: 0.4813 - val_acc: 0.7543
#
# Epoch 20/100
#  - 2s - loss: 0.4621 - acc: 0.7638 - val_loss: 0.5101 - val_acc: 0.7429
#
# Epoch 21/100
#  - 2s - loss: 0.4609 - acc: 0.7662 - val_loss: 0.4897 - val_acc: 0.7543
#
# Epoch 22/100
#  - 2s - loss: 0.4580 - acc: 0.7619 - val_loss: 0.4906 - val_acc: 0.7714
#
# Best validation acc of epoch:
# 0.7714285850524902
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_56163 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_56263 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 4s - loss: 0.6852 - acc: 0.5543 - val_loss: 0.6559 - val_acc: 0.5357
#
# Epoch 2/100
#  - 2s - loss: 0.6537 - acc: 0.6276 - val_loss: 0.6375 - val_acc: 0.5557
#
# Epoch 3/100
#  - 2s - loss: 0.6368 - acc: 0.6157 - val_loss: 0.6264 - val_acc: 0.6986
#
# Epoch 4/100
#  - 2s - loss: 0.6034 - acc: 0.6614 - val_loss: 0.5840 - val_acc: 0.6986
#
# Epoch 5/100
#  - 2s - loss: 0.5860 - acc: 0.6686 - val_loss: 0.6220 - val_acc: 0.6829
#
# Epoch 6/100
#  - 2s - loss: 0.5794 - acc: 0.6790 - val_loss: 0.5664 - val_acc: 0.7029
# Epoch 7/100
#  - 2s - loss: 0.5654 - acc: 0.6786 - val_loss: 0.5438 - val_acc: 0.7157
#
# Epoch 8/100
#  - 2s - loss: 0.5448 - acc: 0.7086 - val_loss: 0.5525 - val_acc: 0.6871
#
# Epoch 9/100
#  - 2s - loss: 0.5503 - acc: 0.7052 - val_loss: 0.5636 - val_acc: 0.6486
#
# Epoch 10/100
#  - 2s - loss: 0.5392 - acc: 0.7048 - val_loss: 0.5372 - val_acc: 0.7257
#
# Epoch 11/100
#  - 2s - loss: 0.5309 - acc: 0.7057 - val_loss: 0.5175 - val_acc: 0.7329
#
# Epoch 12/100
#  - 2s - loss: 0.5189 - acc: 0.7257 - val_loss: 0.5394 - val_acc: 0.6743
#
# Epoch 13/100
#  - 2s - loss: 0.5227 - acc: 0.7105 - val_loss: 0.5057 - val_acc: 0.7443
#
# Epoch 14/100
#  - 2s - loss: 0.5040 - acc: 0.7300 - val_loss: 0.5170 - val_acc: 0.7129
#
# Epoch 15/100
#  - 2s - loss: 0.5002 - acc: 0.7310 - val_loss: 0.5023 - val_acc: 0.7357
#
# Epoch 16/100
#  - 2s - loss: 0.4915 - acc: 0.7338 - val_loss: 0.5045 - val_acc: 0.7371
#
# Epoch 17/100
#  - 2s - loss: 0.4851 - acc: 0.7424 - val_loss: 0.4870 - val_acc: 0.7486
#
# Epoch 18/100
#  - 2s - loss: 0.4959 - acc: 0.7395 - val_loss: 0.5025 - val_acc: 0.7443
#
# Epoch 19/100
#  - 2s - loss: 0.4875 - acc: 0.7467 - val_loss: 0.5616 - val_acc: 0.6614
#
# Epoch 20/100
#  - 2s - loss: 0.4842 - acc: 0.7529 - val_loss: 0.4865 - val_acc: 0.7514
#
# Epoch 21/100
#  - 2s - loss: 0.4686 - acc: 0.7595 - val_loss: 0.4826 - val_acc: 0.7557
#
# Epoch 22/100
#  - 2s - loss: 0.4694 - acc: 0.7619 - val_loss: 0.4895 - val_acc: 0.7614
#
# Epoch 23/100
#  - 2s - loss: 0.4682 - acc: 0.7562 - val_loss: 0.5173 - val_acc: 0.7229
#
# Epoch 24/100
#  - 2s - loss: 0.4511 - acc: 0.7724 - val_loss: 0.4805 - val_acc: 0.7614
#
# Epoch 25/100
#  - 2s - loss: 0.4539 - acc: 0.7662 - val_loss: 0.5122 - val_acc: 0.7529
#
# Epoch 26/100
#  - 2s - loss: 0.4544 - acc: 0.7567 - val_loss: 0.4765 - val_acc: 0.7614
#
# Epoch 27/100
#  - 2s - loss: 0.4513 - acc: 0.7757 - val_loss: 0.5081 - val_acc: 0.7386
#
# Epoch 28/100
#  - 2s - loss: 0.4536 - acc: 0.7700 - val_loss: 0.5281 - val_acc: 0.7114
#
# Epoch 29/100
#  - 2s - loss: 0.4458 - acc: 0.7771 - val_loss: 0.4905 - val_acc: 0.7586
#
# Epoch 30/100
#  - 2s - loss: 0.4349 - acc: 0.7833 - val_loss: 0.4850 - val_acc: 0.7629
#
# Best validation acc of epoch:
# 0.7628571391105652
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_62144 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_62244 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 2s - loss: 0.6921 - acc: 0.5276 - val_loss: 0.6724 - val_acc: 0.6286
#
# Epoch 2/100
#  - 2s - loss: 0.6744 - acc: 0.5781 - val_loss: 0.6593 - val_acc: 0.6843
#
# Epoch 3/100
#  - 2s - loss: 0.6489 - acc: 0.5995 - val_loss: 0.6394 - val_acc: 0.6929
#
# Epoch 4/100
#  - 2s - loss: 0.6258 - acc: 0.6343 - val_loss: 0.6088 - val_acc: 0.6243
#
# Epoch 5/100
#  - 2s - loss: 0.6085 - acc: 0.6495 - val_loss: 0.5891 - val_acc: 0.6986
#
# Epoch 6/100
#  - 2s - loss: 0.6064 - acc: 0.6557 - val_loss: 0.5900 - val_acc: 0.7000
#
# Epoch 7/100
#  - 2s - loss: 0.5914 - acc: 0.6671 - val_loss: 0.5635 - val_acc: 0.6900
#
# Epoch 8/100
#  - 2s - loss: 0.5794 - acc: 0.6752 - val_loss: 0.6012 - val_acc: 0.6214
#
# Epoch 9/100
#  - 2s - loss: 0.5773 - acc: 0.6814 - val_loss: 0.5546 - val_acc: 0.6986
#
# Epoch 10/100
#  - 2s - loss: 0.5660 - acc: 0.6848 - val_loss: 0.5390 - val_acc: 0.7114
#
# Epoch 11/100
#  - 2s - loss: 0.5450 - acc: 0.7019 - val_loss: 0.5391 - val_acc: 0.7086
#
# Epoch 12/100
#  - 2s - loss: 0.5485 - acc: 0.7076 - val_loss: 0.5275 - val_acc: 0.7214
#
# Epoch 13/100
#  - 2s - loss: 0.5393 - acc: 0.7067 - val_loss: 0.5357 - val_acc: 0.6914
#
# Epoch 14/100
#  - 2s - loss: 0.5332 - acc: 0.7143 - val_loss: 0.5158 - val_acc: 0.7529
#
# Epoch 15/100
#  - 2s - loss: 0.5240 - acc: 0.7243 - val_loss: 0.5236 - val_acc: 0.7257
#
# Epoch 16/100
#  - 2s - loss: 0.5114 - acc: 0.7362 - val_loss: 0.5259 - val_acc: 0.7214
#
# Epoch 17/100
#  - 2s - loss: 0.5251 - acc: 0.7157 - val_loss: 0.5038 - val_acc: 0.7386
#
# Epoch 18/100
#  - 2s - loss: 0.5074 - acc: 0.7367 - val_loss: 0.4970 - val_acc: 0.7529
#
# Epoch 19/100
#  - 2s - loss: 0.5172 - acc: 0.7271 - val_loss: 0.4946 - val_acc: 0.7529
#
# Epoch 20/100
#  - 2s - loss: 0.5264 - acc: 0.7167 - val_loss: 0.5343 - val_acc: 0.7014
#
# Epoch 21/100
#  - 2s - loss: 0.5098 - acc: 0.7290 - val_loss: 0.5022 - val_acc: 0.7343
#
# Epoch 22/100
#  - 2s - loss: 0.4962 - acc: 0.7371 - val_loss: 0.4895 - val_acc: 0.7571
#
# Epoch 23/100
#  - 2s - loss: 0.4940 - acc: 0.7505 - val_loss: 0.4875 - val_acc: 0.7643
#
# Epoch 24/100
#  - 2s - loss: 0.4899 - acc: 0.7419 - val_loss: 0.4988 - val_acc: 0.7300
#
# Epoch 25/100
#  - 2s - loss: 0.4823 - acc: 0.7476 - val_loss: 0.4827 - val_acc: 0.7686
#
# Epoch 26/100
#  - 2s - loss: 0.4864 - acc: 0.7514 - val_loss: 0.4829 - val_acc: 0.7600
#
# Epoch 27/100
#  - 2s - loss: 0.4970 - acc: 0.7400 - val_loss: 0.4925 - val_acc: 0.7471
#
# Epoch 28/100
#  - 2s - loss: 0.4875 - acc: 0.7514 - val_loss: 0.4920 - val_acc: 0.7429
#
# Epoch 29/100
#  - 2s - loss: 0.4806 - acc: 0.7514 - val_loss: 0.4874 - val_acc: 0.7443
#
# Best validation acc of epoch:
# 0.7685714364051819
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Train on 2100 samples, validate on 700 samples
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_67983 in device /job:localhost/replica:0/task:0/device:GPU:0
#
# Executing op __inference_keras_scratch_graph_68083 in device /job:localhost/replica:0/task:0/device:GPU:0
#
#  - 2s - loss: 0.6965 - acc: 0.5133 - val_loss: 0.6813 - val_acc: 0.5200
#
# Epoch 2/100
#  - 2s - loss: 0.6771 - acc: 0.5862 - val_loss: 0.6579 - val_acc: 0.5771
#
# Epoch 3/100
#  - 2s - loss: 0.6613 - acc: 0.5995 - val_loss: 0.6396 - val_acc: 0.6800
#
# Epoch 4/100
#  - 2s - loss: 0.6378 - acc: 0.6252 - val_loss: 0.6137 - val_acc: 0.6357
#
# Epoch 5/100
#  - 2s - loss: 0.6114 - acc: 0.6619 - val_loss: 0.5898 - val_acc: 0.6814
#
# Epoch 6/100
#  - 2s - loss: 0.5962 - acc: 0.6648 - val_loss: 0.5876 - val_acc: 0.6600
#
# Epoch 7/100
#  - 2s - loss: 0.5881 - acc: 0.6733 - val_loss: 0.5649 - val_acc: 0.7171
#
# Epoch 8/100
#  - 2s - loss: 0.5811 - acc: 0.6914 - val_loss: 0.5671 - val_acc: 0.7100
#
# Epoch 9/100
#  - 2s - loss: 0.5765 - acc: 0.6824 - val_loss: 0.5545 - val_acc: 0.7014
#
# Epoch 10/100
#  - 2s - loss: 0.5588 - acc: 0.6995 - val_loss: 0.5432 - val_acc: 0.7129
#
# Epoch 11/100
#  - 2s - loss: 0.5487 - acc: 0.7119 - val_loss: 0.5336 - val_acc: 0.7357
#
# Epoch 12/100
#  - 2s - loss: 0.5566 - acc: 0.7029 - val_loss: 0.5322 - val_acc: 0.7314
#
# Epoch 13/100
#  - 2s - loss: 0.5444 - acc: 0.7100 - val_loss: 0.5279 - val_acc: 0.7400
#
# Epoch 14/100
#  - 2s - loss: 0.5424 - acc: 0.7195 - val_loss: 0.5294 - val_acc: 0.7243
#
# Epoch 15/100
#  - 2s - loss: 0.5451 - acc: 0.7110 - val_loss: 0.5234 - val_acc: 0.7257
#
# Epoch 16/100
#  - 2s - loss: 0.5492 - acc: 0.6990 - val_loss: 0.5212 - val_acc: 0.7471
#
# Epoch 17/100
#  - 2s - loss: 0.5282 - acc: 0.7219 - val_loss: 0.5388 - val_acc: 0.7057
#
# Epoch 18/100
#  - 2s - loss: 0.5226 - acc: 0.7281 - val_loss: 0.5147 - val_acc: 0.7471
#
# Epoch 19/100
#  - 2s - loss: 0.5257 - acc: 0.7200 - val_loss: 0.5949 - val_acc: 0.6357
#
# Epoch 20/100
#  - 2s - loss: 0.5666 - acc: 0.6767 - val_loss: 0.5296 - val_acc: 0.7029
#
# Epoch 21/100
#  - 2s - loss: 0.5368 - acc: 0.7033 - val_loss: 0.5073 - val_acc: 0.7629
#
# Epoch 22/100
#  - 2s - loss: 0.5065 - acc: 0.7348 - val_loss: 0.5018 - val_acc: 0.7657
#
# Epoch 23/100
#  - 2s - loss: 0.5118 - acc: 0.7290 - val_loss: 0.4965 - val_acc: 0.7429
#
# Epoch 24/100
#  - 2s - loss: 0.4972 - acc: 0.7443 - val_loss: 0.4904 - val_acc: 0.7586
#
# Epoch 25/100
#  - 2s - loss: 0.5008 - acc: 0.7386 - val_loss: 0.4903 - val_acc: 0.7514
#
# Epoch 26/100
#  - 2s - loss: 0.5049 - acc: 0.7381 - val_loss: 0.5105 - val_acc: 0.7429
#
# Epoch 27/100
#  - 2s - loss: 0.5040 - acc: 0.7324 - val_loss: 0.4972 - val_acc: 0.7500
#
# Epoch 28/100
#  - 2s - loss: 0.4937 - acc: 0.7348 - val_loss: 0.4926 - val_acc: 0.7557
#
# Epoch 29/100
#  - 2s - loss: 0.4837 - acc: 0.7457 - val_loss: 0.4837 - val_acc: 0.7700
#
# Epoch 30/100
#  - 2s - loss: 0.5019 - acc: 0.7286 - val_loss: 0.5079 - val_acc: 0.7457
#
# Epoch 31/100
#  - 2s - loss: 0.4868 - acc: 0.7476 - val_loss: 0.4876 - val_acc: 0.7471
#
# Epoch 32/100
#  - 2s - loss: 0.4741 - acc: 0.7510 - val_loss: 0.4816 - val_acc: 0.7629
#
# Epoch 33/100
#  - 2s - loss: 0.4760 - acc: 0.7490 - val_loss: 0.4779 - val_acc: 0.7543
#
# Epoch 34/100
#  - 2s - loss: 0.4744 - acc: 0.7457 - val_loss: 0.4917 - val_acc: 0.7686
#
# Epoch 35/100
#  - 2s - loss: 0.4730 - acc: 0.7495 - val_loss: 0.4830 - val_acc: 0.7586
#
# Epoch 36/100
#  - 2s - loss: 0.4659 - acc: 0.7595 - val_loss: 0.4836 - val_acc: 0.7400
#
# Epoch 37/100
#  - 2s - loss: 0.4760 - acc: 0.7438 - val_loss: 0.5007 - val_acc: 0.7257
#
# Best validation acc of epoch:
# 0.7699999809265137
# 100%|██████████| 5/5 [05:17<00:00, 63.46s/it, best loss: -0.7714285850524902]
# /home/valborsf/Documents/UOC/PFMProject/DataNew4/CSV/
# (2100, 150, 150, 3)
# (700, 150, 150, 3)
# (700, 150, 150, 3)
# Evalutation of best performing model:
# 700/700 [==============================] - 1s 939us/step
# [0.5009929624625614, 0.75]
# Best performing model chosen hyper-parameters:
# {'Dense': 512, 'batch_size': 64}

# %%
# Results Dense layer 512
# Batch size 64
