# %% [markdown]
# # Notebook- Fast Feature Extraction  -Model K6_0
# # Author : V.Albors   Date : 1.12.2019
# # Purpose : Fast Feature Extraction without Data augmentation ( on VGG16 and ResNet50 )
#
#
# **Input** :
#   * CSV files that identify the images to use as train and validation. CSV files are in directory csv_dir
#   * Images from train and validation. Images are in directory : imag_dir
#   * Saved model. Model is in directory : model_bin_dir
#
# **Output**:
#   * Download of the model trained with train dataset
#   * Download the history of the model in order to be evaluated
#
# **Process**:
#   * Import VGG16 or ResNet50
#   * Configure the convolutional base  ( use weights from imagenet, no use the dense classifier on top, shape of tensors feed )
#   *  Print Network, save network
#   *  Dataframes are created for Training and Validation
#   *  Extract features from the data and labels using the  conv.base.predict  operation.
#   *  Flatten the extracted features knowing the dimensions of the last layer of the VGG16 or ResNet50 .
#   *  Build a densely connected classifier
#   *  Compile network
#   *  Train the model  using the flatten extracted features using model.fit
#   *  With Callbacks
#   *  The model is Saved

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

tf.keras.backend.clear_session()  # Reset

# %%
import tensorflow as tf
#gpus = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.config.experimental.list_physical_devices('GPU') 
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.debugging.set_log_device_placement(True)

# %%
#Tensorflow version 
print(tf.__version__)
from tensorflow.python.platform import build_info as tf_build_info
print(tf_build_info.cuda_version_number)
# Cuda Version 9.0 in v1.10.0
print(tf_build_info.cudnn_version_number)
# CudNN 7 in v1.10.0

# %%
# Define the name of the model, directories & if to train the model 
#Pre_model = "ResNet50"
Pre_model = "VGG16"
Model_directory = "MODELK6"
if Pre_model == "ResNet50":
    Model_name = "Model6_0_ResNet50"
else:
    Model_name = "Model6_0_VGG16"
TRAIN = True

# %%
# Import routines
import sys  
subrc_dir = "/home/valborsf/Documents/UOC/PFMProject/"


sys.path.append(subrc_dir)  
from  Models_routines import *
import inspect

# List functions inside the module
import Models_routines as module
functions = inspect.getmembers(module, inspect.isfunction)
lsfunctions = [item[0] for item in functions]
print ( lsfunctions )
# Out:
# ['confusion_ROC_AUC', 'create_column_tensor', 'create_label_tensor', 'create_val_test', 'define_dirs', 'extract_images_bm', 'extract_images_train', 'load_hist_model', 'load_images', 'model_load', 'plot_save_acc_loss', 'print_network', 'process_clinical_info', 'read_dataframes', 'read_dataframes_tables', 'reproducible_results', 'save_model', 'save_network_json', 'start', 'stop', 'to_one_hot', 'to_one_hot_words', 'xi_squared']

# %%
# Reproducible results 
reproducible_results ()

# %%
#Define directories
(root_dir,json_dir,imag_dir,csv_dir,model_json_dir,model_bin_dir,results_dir,Tensor_dir) = define_dirs(Model_directory)

# %%
# New dataset without SONIC disturbing images
json_dir =  root_dir +"/DataNew/ALL_JSON/"                # .json dir images
imag_dir =  root_dir +"/DataNew/ALL_IMAGES/"              # .png dir - images

# directories for  CSV's
csv_dir =  root_dir +"/DataNew4/CSV/"                      # .csv dir - dftrain, dfval, dftest

# %%
if Pre_model == "ResNet50":
    from keras.applications import ResNet50
elif Pre_model == "VGG16":
    from keras.applications import VGG16

# %%
if Pre_model == "ResNet50":
       conv_base = ResNet50 ( weights='imagenet',  # Weight checkpoint from which to initialize the model 
                     include_top = False,        # No include the dense connected classifier on top
                     input_shape = (150,150,3))  # Shape of the image tensors to feed in the network

elif Pre_model == "VGG16":
       conv_base = VGG16  ( weights='imagenet',    # Weight checkpoint from which to initialize the model 
                     include_top = False,        # No include the dense connected classifier on top
                     input_shape = (150,150,3))  # Shape of the image tensors to feed in the network
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 19s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Print Network 
#print_network (results_dir, conv_base, Model_name)
#Save Network 
save_network_json (model_json_dir, conv_base, Model_name)

# %%
# Load train,validation & Test 
(dftrain, dfval, dftest) = read_dataframes(csv_dir)
# Out:
# /home/valborsf/Documents/UOC/PFMProject/DataNew3/CSV/

# %%
# This is time consuming !
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)
batch_size = 32

def extract_features( dataframe, sample_count, Pre_model):
    if Pre_model == "VGG16":
           features = np.zeros(shape=(sample_count,4,4,512))  #Last layer VGG16
    elif Pre_model == "ResNet50":
           features = np.zeros(shape=(sample_count,5,5,2048))  #Last layer ResNet50
    labels = np.zeros (shape=(sample_count))
    generator = datagen.flow_from_dataframe(
        dataframe=dataframe,       # Data frame with info of the files and targets
        directory=imag_dir,        # path to the directory to read the images from
        x_col='file_name_ext',     # column in the data frame that contains the file names 
        y_col='bm',                # column in the data frame that has the target data
        target_size=(150, 150),    # dimensions that the images will be resized
        batch_size=batch_size,             # size of the batches of data (default: 32).
        class_mode='binary')       # Mode for yielding the targets:1D numpy array of binary labels
    i=0
    
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch)
        features[i * batch_size :(i+1)* batch_size] = features_batch
        labels [i*batch_size : (i+1) * batch_size]= labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels 

num_train = 2100
num_val = 700
num_test = 700

train_features, train_labels = extract_features(dftrain,  num_train, Pre_model)
validation_features, validation_labels = extract_features ( dfval, num_val, Pre_model)
test_features, test_labels = extract_features(dftest, num_test, Pre_model)
# Out:
# Found 2614 validated image filenames belonging to 2 classes.
# Found 872 validated image filenames belonging to 2 classes.
# Found 870 validated image filenames belonging to 2 classes.

# %%
# Check tensors 
print ( Pre_model)
print (type (train_features) )
print (type (train_labels) )
print (train_features.shape) 
print (train_labels.shape) 
#print (train_features[0,0,0])
#print (train_labels[0])
# Out:
# VGG16
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (2614, 4, 4, 512)
# (2614,)

# %%
# Preprocess Tensors shape for the different PreNets

if Pre_model == "ResNet50":
# ResNet50
       train_features = np.reshape ( train_features, (num_train, 5*5*2048))
       validation_features = np.reshape ( validation_features, (num_val, 5*5*2048))
       test_features = np.reshape ( test_features, (num_test, 5*5*2048))
elif Pre_model == "VGG16":
#VGG16
       train_features = np.reshape ( train_features, (num_train, 4*4*512))
       validation_features = np.reshape ( validation_features, (num_val, 4*4*512))
       test_features = np.reshape ( test_features, (num_test, 4*4*512))

# %%
#Build Network 
from keras import layers
from keras import models
from keras.regularizers import l2
model = models.Sequential ()

if Pre_model == "VGG16":
    model.add(layers.Dense(256, kernel_regularizer=l2(0.0005), activation='relu', input_dim = 4*4*512))    # VGG16

elif Pre_model == "ResNet50":
    model.add(layers.Dense(256, kernel_regularizer=l2(0.0005), activation='relu', input_dim = 5*5*2048))  # ResNet50

model.add(layers.Dense(1000, kernel_regularizer=l2(0.0005), activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(200, kernel_regularizer=l2(0.0005), activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Compile Network 
from keras import optimizers 
model.compile ( loss='binary_crossentropy',
#               optimizer = optimizers.RMSprop(lr=1e-4),
               optimizer = optimizers.Adam(lr=1e-4),
               metrics= ['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              257000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 200)               200200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 2,554,809
# Trainable params: 2,554,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Print Network 
Model_name_train = Model_name + "_train"
#print_network (results_dir, model, Model_name_train)
#Save Network 
save_network_json (model_json_dir, model, Model_name_train)

# %%
# Callbackt to be used 
import keras
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

callbacks_list = [
# No early stopping when augmentation 
#         keras.callbacks.EarlyStopping (
#             monitor = 'acc',             # Monitors the accuracy
#             patience = 2,),              # Interrupt if acc no improve in 3 epochs

#  ModelCheckpoint to store the weights of the best performing epoch. 
    
         keras.callbacks.ModelCheckpoint(filepath=model_bin_dir+"Best_weights"+Model_name+".hdf5", 
             monitor = 'val_loss', # Won't overwritte the model file unless val_loss has
             verbose=1,            # improve 
             save_best_only=True),
         
#         keras.callbacks.TensorBoard(
#             log_dir =  Tensor_dir, 
#            histogram_freq = 0,  ) # No histograms - validation data must be provided as a tensor
          ]

# %%
# train Network
if TRAIN :
    history = model.fit ( train_features, train_labels, 
                      epochs = 100,
                      callbacks=callbacks_list,   
                      batch_size = 32, 
                      validation_data = ( validation_features, validation_labels))
    save_model(model, history, model_bin_dir, Model_name)
# Out:
# Train on 2614 samples, validate on 872 samples
# Epoch 1/100
# 2614/2614 [==============================] - 1s 290us/step - loss: 1.2099 - acc: 0.6041 - val_loss: 1.0548 - val_acc: 0.7144
#
# Epoch 00001: val_loss improved from inf to 1.05476, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 2/100
# 2614/2614 [==============================] - 0s 144us/step - loss: 1.0371 - acc: 0.6886 - val_loss: 0.9659 - val_acc: 0.7213
#
# Epoch 00002: val_loss improved from 1.05476 to 0.96589, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 3/100
# 2614/2614 [==============================] - 0s 180us/step - loss: 0.9519 - acc: 0.7280 - val_loss: 0.9007 - val_acc: 0.7408
#
# Epoch 00003: val_loss improved from 0.96589 to 0.90068, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 4/100
# 2614/2614 [==============================] - 0s 160us/step - loss: 0.8883 - acc: 0.7429 - val_loss: 0.8667 - val_acc: 0.7385
#
# Epoch 00004: val_loss improved from 0.90068 to 0.86666, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 5/100
# 2614/2614 [==============================] - 0s 152us/step - loss: 0.8415 - acc: 0.7605 - val_loss: 0.8327 - val_acc: 0.7489
#
# Epoch 00005: val_loss improved from 0.86666 to 0.83267, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 6/100
# 2614/2614 [==============================] - 0s 162us/step - loss: 0.8011 - acc: 0.7720 - val_loss: 0.8184 - val_acc: 0.7511
#
# Epoch 00006: val_loss improved from 0.83267 to 0.81843, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 7/100
# 2614/2614 [==============================] - 0s 148us/step - loss: 0.7600 - acc: 0.7953 - val_loss: 0.7939 - val_acc: 0.7523
#
# Epoch 00007: val_loss improved from 0.81843 to 0.79387, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 8/100
# 2614/2614 [==============================] - 0s 170us/step - loss: 0.7262 - acc: 0.8037 - val_loss: 0.7873 - val_acc: 0.7500
#
# Epoch 00008: val_loss improved from 0.79387 to 0.78731, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 9/100
# 2614/2614 [==============================] - 0s 178us/step - loss: 0.7072 - acc: 0.8087 - val_loss: 0.7807 - val_acc: 0.7489
#
# Epoch 00009: val_loss improved from 0.78731 to 0.78074, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 10/100
# 2614/2614 [==============================] - 0s 144us/step - loss: 0.6584 - acc: 0.8279 - val_loss: 0.7931 - val_acc: 0.7569
#
# Epoch 00010: val_loss did not improve from 0.78074
# Epoch 11/100
# 2614/2614 [==============================] - 0s 191us/step - loss: 0.6284 - acc: 0.8397 - val_loss: 0.7864 - val_acc: 0.7523
#
# Epoch 00011: val_loss did not improve from 0.78074
# Epoch 12/100
# 2614/2614 [==============================] - 0s 191us/step - loss: 0.5967 - acc: 0.8600 - val_loss: 0.7744 - val_acc: 0.7443
#
# Epoch 00012: val_loss improved from 0.78074 to 0.77435, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 13/100
# 2614/2614 [==============================] - 0s 146us/step - loss: 0.5733 - acc: 0.8650 - val_loss: 0.7833 - val_acc: 0.7592
#
# Epoch 00013: val_loss did not improve from 0.77435
# Epoch 14/100
# 2614/2614 [==============================] - 1s 199us/step - loss: 0.5597 - acc: 0.8703 - val_loss: 0.7626 - val_acc: 0.7626
#
# Epoch 00014: val_loss improved from 0.77435 to 0.76259, saving model to /home/valborsf/Documents/UOC/PFMProject/MODELN6/BMODEL/Best_weightsModel6_0_VGG16.hdf5
# Epoch 15/100
# 2614/2614 [==============================] - 0s 157us/step - loss: 0.5351 - acc: 0.8757 - val_loss: 0.7737 - val_acc: 0.7466
#
# Epoch 00015: val_loss did not improve from 0.76259
# Epoch 16/100
# 2614/2614 [==============================] - 0s 160us/step - loss: 0.5027 - acc: 0.8929 - val_loss: 0.8135 - val_acc: 0.7374
#
# Epoch 00016: val_loss did not improve from 0.76259
# Epoch 17/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.4776 - acc: 0.9021 - val_loss: 0.9188 - val_acc: 0.7317
#
# Epoch 00017: val_loss did not improve from 0.76259
# Epoch 18/100
# 2614/2614 [==============================] - 0s 173us/step - loss: 0.4551 - acc: 0.9078 - val_loss: 0.8471 - val_acc: 0.7477
#
# Epoch 00018: val_loss did not improve from 0.76259
# Epoch 19/100
# 2614/2614 [==============================] - 0s 170us/step - loss: 0.4415 - acc: 0.9097 - val_loss: 0.9045 - val_acc: 0.7259
#
# Epoch 00019: val_loss did not improve from 0.76259
# Epoch 20/100
# 2614/2614 [==============================] - 0s 159us/step - loss: 0.4267 - acc: 0.9189 - val_loss: 0.8762 - val_acc: 0.7466
#
# Epoch 00020: val_loss did not improve from 0.76259
# Epoch 21/100
# 2614/2614 [==============================] - 0s 162us/step - loss: 0.3769 - acc: 0.9388 - val_loss: 0.9249 - val_acc: 0.7305
#
# Epoch 00021: val_loss did not improve from 0.76259
# Epoch 22/100
# 2614/2614 [==============================] - 0s 171us/step - loss: 0.3667 - acc: 0.9422 - val_loss: 0.9713 - val_acc: 0.7489
#
# Epoch 00022: val_loss did not improve from 0.76259
# Epoch 23/100
# 2614/2614 [==============================] - 0s 173us/step - loss: 0.3571 - acc: 0.9438 - val_loss: 0.9693 - val_acc: 0.7374
#
# Epoch 00023: val_loss did not improve from 0.76259
# Epoch 24/100
# 2614/2614 [==============================] - 0s 176us/step - loss: 0.3353 - acc: 0.9522 - val_loss: 1.0049 - val_acc: 0.7351
#
# Epoch 00024: val_loss did not improve from 0.76259
# Epoch 25/100
# 2614/2614 [==============================] - 0s 175us/step - loss: 0.3305 - acc: 0.9484 - val_loss: 1.0780 - val_acc: 0.7477
#
# Epoch 00025: val_loss did not improve from 0.76259
# Epoch 26/100
# 2614/2614 [==============================] - 0s 146us/step - loss: 0.3320 - acc: 0.9503 - val_loss: 1.0432 - val_acc: 0.7248
#
# Epoch 00026: val_loss did not improve from 0.76259
# Epoch 27/100
# 2614/2614 [==============================] - 0s 145us/step - loss: 0.2988 - acc: 0.9637 - val_loss: 1.0366 - val_acc: 0.7339
#
# Epoch 00027: val_loss did not improve from 0.76259
# Epoch 28/100
# 2614/2614 [==============================] - 0s 163us/step - loss: 0.2903 - acc: 0.9656 - val_loss: 1.1085 - val_acc: 0.7339
#
# Epoch 00028: val_loss did not improve from 0.76259
# Epoch 29/100
# 2614/2614 [==============================] - 0s 168us/step - loss: 0.2835 - acc: 0.9682 - val_loss: 1.1324 - val_acc: 0.7466
#
# Epoch 00029: val_loss did not improve from 0.76259
# Epoch 30/100
# 2614/2614 [==============================] - 0s 168us/step - loss: 0.2581 - acc: 0.9759 - val_loss: 1.1270 - val_acc: 0.7271
#
# Epoch 00030: val_loss did not improve from 0.76259
# Epoch 31/100
# 2614/2614 [==============================] - 0s 170us/step - loss: 0.2707 - acc: 0.9671 - val_loss: 1.1465 - val_acc: 0.7477
#
# Epoch 00031: val_loss did not improve from 0.76259
# Epoch 32/100
# 2614/2614 [==============================] - 0s 169us/step - loss: 0.2561 - acc: 0.9721 - val_loss: 1.2086 - val_acc: 0.7339
#
# Epoch 00032: val_loss did not improve from 0.76259
# Epoch 33/100
# 2614/2614 [==============================] - 0s 169us/step - loss: 0.2415 - acc: 0.9805 - val_loss: 1.4230 - val_acc: 0.7190
#
# Epoch 00033: val_loss did not improve from 0.76259
# Epoch 34/100
# 2614/2614 [==============================] - 0s 159us/step - loss: 0.2194 - acc: 0.9901 - val_loss: 1.2769 - val_acc: 0.7282
#
# Epoch 00034: val_loss did not improve from 0.76259
# Epoch 35/100
# 2614/2614 [==============================] - 0s 159us/step - loss: 0.2191 - acc: 0.9851 - val_loss: 1.3409 - val_acc: 0.7385
#
# Epoch 00035: val_loss did not improve from 0.76259
# Epoch 36/100
# 2614/2614 [==============================] - 0s 166us/step - loss: 0.2254 - acc: 0.9836 - val_loss: 1.2790 - val_acc: 0.7317
#
# Epoch 00036: val_loss did not improve from 0.76259
# Epoch 37/100
# 2614/2614 [==============================] - 0s 160us/step - loss: 0.2345 - acc: 0.9782 - val_loss: 1.1647 - val_acc: 0.7282
# Epoch 00037: val_loss did not improve from 0.76259
# Epoch 38/100
# 2614/2614 [==============================] - 0s 166us/step - loss: 0.2073 - acc: 0.9874 - val_loss: 1.3802 - val_acc: 0.7156
#
# Epoch 00038: val_loss did not improve from 0.76259
# Epoch 39/100
# 2614/2614 [==============================] - 1s 195us/step - loss: 0.1939 - acc: 0.9901 - val_loss: 1.4046 - val_acc: 0.7202
#
# Epoch 00039: val_loss did not improve from 0.76259
# Epoch 40/100
# 2614/2614 [==============================] - 1s 227us/step - loss: 0.1840 - acc: 0.9931 - val_loss: 1.3455 - val_acc: 0.7431
#
# Epoch 00040: val_loss did not improve from 0.76259
# Epoch 41/100
# 2614/2614 [==============================] - 1s 247us/step - loss: 0.1936 - acc: 0.9843 - val_loss: 1.4681 - val_acc: 0.6835
#
# Epoch 00041: val_loss did not improve from 0.76259
# Epoch 42/100
# 2614/2614 [==============================] - 1s 203us/step - loss: 0.1811 - acc: 0.9923 - val_loss: 1.3723 - val_acc: 0.7294
#
# Epoch 00042: val_loss did not improve from 0.76259
# Epoch 43/100
# 2614/2614 [==============================] - 1s 201us/step - loss: 0.1832 - acc: 0.9885 - val_loss: 1.3555 - val_acc: 0.7248
#
# Epoch 00043: val_loss did not improve from 0.76259
# Epoch 44/100
# 2614/2614 [==============================] - 1s 201us/step - loss: 0.1727 - acc: 0.9939 - val_loss: 1.4188 - val_acc: 0.7397
#
# Epoch 00044: val_loss did not improve from 0.76259
# Epoch 45/100
# 2614/2614 [==============================] - 1s 199us/step - loss: 0.1572 - acc: 0.9969 - val_loss: 1.4006 - val_acc: 0.7477
#
# Epoch 00045: val_loss did not improve from 0.76259
# Epoch 46/100
# 2614/2614 [==============================] - 1s 200us/step - loss: 0.1763 - acc: 0.9897 - val_loss: 1.4104 - val_acc: 0.7397
#
# Epoch 00046: val_loss did not improve from 0.76259
# Epoch 47/100
# 2614/2614 [==============================] - 0s 178us/step - loss: 0.2425 - acc: 0.9602 - val_loss: 1.1595 - val_acc: 0.7294
#
# Epoch 00047: val_loss did not improve from 0.76259
# Epoch 48/100
# 2614/2614 [==============================] - 0s 138us/step - loss: 0.2608 - acc: 0.9507 - val_loss: 0.9570 - val_acc: 0.7592
#
# Epoch 00048: val_loss did not improve from 0.76259
# Epoch 49/100
# 2614/2614 [==============================] - 0s 148us/step - loss: 0.1828 - acc: 0.9855 - val_loss: 1.2511 - val_acc: 0.7259
#
# Epoch 00049: val_loss did not improve from 0.76259
# Epoch 50/100
# 2614/2614 [==============================] - 0s 157us/step - loss: 0.1556 - acc: 0.9954 - val_loss: 1.4683 - val_acc: 0.7259
#
# Epoch 00050: val_loss did not improve from 0.76259
# Epoch 51/100
# 2614/2614 [==============================] - 0s 163us/step - loss: 0.1523 - acc: 0.9950 - val_loss: 1.4302 - val_acc: 0.7328
#
# Epoch 00051: val_loss did not improve from 0.76259
# Epoch 52/100
# 2614/2614 [==============================] - 1s 195us/step - loss: 0.1422 - acc: 0.9977 - val_loss: 1.3991 - val_acc: 0.7374
#
# Epoch 00052: val_loss did not improve from 0.76259
# Epoch 53/100
# 2614/2614 [==============================] - 0s 157us/step - loss: 0.1389 - acc: 0.9977 - val_loss: 1.3913 - val_acc: 0.7317
#
# Epoch 00053: val_loss did not improve from 0.76259
# Epoch 54/100
# 2614/2614 [==============================] - 0s 153us/step - loss: 0.1369 - acc: 0.9977 - val_loss: 1.4322 - val_acc: 0.7408
#
# Epoch 00054: val_loss did not improve from 0.76259
# Epoch 55/100
# 2614/2614 [==============================] - 0s 141us/step - loss: 0.1379 - acc: 0.9966 - val_loss: 1.4238 - val_acc: 0.7294
#
# Epoch 00055: val_loss did not improve from 0.76259
# Epoch 56/100
# 2614/2614 [==============================] - 0s 146us/step - loss: 0.1335 - acc: 0.9973 - val_loss: 1.5872 - val_acc: 0.7190
#
# Epoch 00056: val_loss did not improve from 0.76259
# Epoch 57/100
# 2614/2614 [==============================] - 0s 150us/step - loss: 0.1326 - acc: 0.9969 - val_loss: 1.4164 - val_acc: 0.7282
#
# Epoch 00057: val_loss did not improve from 0.76259
# Epoch 58/100
# 2614/2614 [==============================] - 0s 149us/step - loss: 0.1662 - acc: 0.9816 - val_loss: 1.0526 - val_acc: 0.7305
#
# Epoch 00058: val_loss did not improve from 0.76259
# Epoch 59/100
# 2614/2614 [==============================] - 0s 150us/step - loss: 0.1451 - acc: 0.9912 - val_loss: 1.3101 - val_acc: 0.7362
#
# Epoch 00059: val_loss did not improve from 0.76259
# Epoch 60/100
# 2614/2614 [==============================] - 0s 154us/step - loss: 0.1234 - acc: 0.9977 - val_loss: 1.4136 - val_acc: 0.7271
#
# Epoch 00060: val_loss did not improve from 0.76259
# Epoch 61/100
# 2614/2614 [==============================] - 0s 165us/step - loss: 0.1251 - acc: 0.9962 - val_loss: 1.5919 - val_acc: 0.7236
#
# Epoch 00061: val_loss did not improve from 0.76259
# Epoch 62/100
# 2614/2614 [==============================] - 0s 157us/step - loss: 0.1159 - acc: 0.9977 - val_loss: 1.4600 - val_acc: 0.7443
#
# Epoch 00062: val_loss did not improve from 0.76259
# Epoch 63/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.1439 - acc: 0.9893 - val_loss: 1.4336 - val_acc: 0.7271
#
# Epoch 00063: val_loss did not improve from 0.76259
# Epoch 64/100
# 2614/2614 [==============================] - 0s 160us/step - loss: 0.1454 - acc: 0.9839 - val_loss: 1.3107 - val_acc: 0.7420
#
# Epoch 00064: val_loss did not improve from 0.76259
# Epoch 65/100
# 2614/2614 [==============================] - 0s 168us/step - loss: 0.1342 - acc: 0.9904 - val_loss: 1.2707 - val_acc: 0.7408
#
# Epoch 00065: val_loss did not improve from 0.76259
# Epoch 66/100
# 2614/2614 [==============================] - 0s 161us/step - loss: 0.1105 - acc: 0.9981 - val_loss: 1.4883 - val_acc: 0.7408
#
# Epoch 00066: val_loss did not improve from 0.76259
# Epoch 67/100
# 2614/2614 [==============================] - 0s 190us/step - loss: 0.1080 - acc: 0.9977 - val_loss: 1.4327 - val_acc: 0.7282
#
# Epoch 00067: val_loss did not improve from 0.76259
# Epoch 68/100
# 2614/2614 [==============================] - 1s 193us/step - loss: 0.1063 - acc: 0.9977 - val_loss: 1.4286 - val_acc: 0.7248
#
# Epoch 00068: val_loss did not improve from 0.76259
# Epoch 69/100
# 2614/2614 [==============================] - 0s 181us/step - loss: 0.1092 - acc: 0.9954 - val_loss: 1.4595 - val_acc: 0.7317
#
# Epoch 00069: val_loss did not improve from 0.76259
# Epoch 70/100
# 2614/2614 [==============================] - 0s 156us/step - loss: 0.0991 - acc: 0.9989 - val_loss: 1.6435 - val_acc: 0.7317
#
# Epoch 00070: val_loss did not improve from 0.76259
# Epoch 71/100
# 2614/2614 [==============================] - 0s 146us/step - loss: 0.1344 - acc: 0.9851 - val_loss: 1.4019 - val_acc: 0.7408
#
# Epoch 00071: val_loss did not improve from 0.76259
# Epoch 72/100
# 2614/2614 [==============================] - 0s 146us/step - loss: 0.1162 - acc: 0.9920 - val_loss: 1.4273 - val_acc: 0.7420
#
# Epoch 00072: val_loss did not improve from 0.76259
# Epoch 73/100
# 2614/2614 [==============================] - 0s 166us/step - loss: 0.1402 - acc: 0.9805 - val_loss: 1.3083 - val_acc: 0.7190
#
# Epoch 00073: val_loss did not improve from 0.76259
# Epoch 74/100
# 2614/2614 [==============================] - 0s 169us/step - loss: 0.1266 - acc: 0.9885 - val_loss: 1.2389 - val_acc: 0.7259
#
# Epoch 00074: val_loss did not improve from 0.76259
# Epoch 75/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.1257 - acc: 0.9874 - val_loss: 1.4004 - val_acc: 0.7317
#
# Epoch 00075: val_loss did not improve from 0.76259
# Epoch 76/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.1017 - acc: 0.9969 - val_loss: 1.3465 - val_acc: 0.7362
#
# Epoch 00076: val_loss did not improve from 0.76259
# Epoch 77/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.0928 - acc: 0.9989 - val_loss: 1.3889 - val_acc: 0.7374
#
# Epoch 00077: val_loss did not improve from 0.76259
# Epoch 78/100
# 2614/2614 [==============================] - 0s 166us/step - loss: 0.0903 - acc: 0.9992 - val_loss: 1.4401 - val_acc: 0.7179
#
# Epoch 00078: val_loss did not improve from 0.76259
# Epoch 79/100
# 2614/2614 [==============================] - 0s 163us/step - loss: 0.0885 - acc: 0.9989 - val_loss: 1.4181 - val_acc: 0.7271
#
# Epoch 00079: val_loss did not improve from 0.76259
# Epoch 80/100
# 2614/2614 [==============================] - 0s 155us/step - loss: 0.0863 - acc: 0.9989 - val_loss: 1.4691 - val_acc: 0.7362
#
# Epoch 00080: val_loss did not improve from 0.76259
# Epoch 81/100
# 2614/2614 [==============================] - 0s 179us/step - loss: 0.0889 - acc: 0.9985 - val_loss: 1.4323 - val_acc: 0.7454
#
# Epoch 00081: val_loss did not improve from 0.76259
# Epoch 82/100
# 2614/2614 [==============================] - 0s 180us/step - loss: 0.0887 - acc: 0.9969 - val_loss: 1.4106 - val_acc: 0.7190
#
# Epoch 00082: val_loss did not improve from 0.76259
# Epoch 83/100
# 2614/2614 [==============================] - 0s 179us/step - loss: 0.0876 - acc: 0.9973 - val_loss: 1.3586 - val_acc: 0.7385
#
# Epoch 00083: val_loss did not improve from 0.76259
# Epoch 84/100
# 2614/2614 [==============================] - 0s 177us/step - loss: 0.0841 - acc: 0.9973 - val_loss: 1.5675 - val_acc: 0.7099
#
# Epoch 00084: val_loss did not improve from 0.76259
# Epoch 85/100
# 2614/2614 [==============================] - 0s 178us/step - loss: 0.0851 - acc: 0.9977 - val_loss: 1.4862 - val_acc: 0.7374
#
# Epoch 00085: val_loss did not improve from 0.76259
# Epoch 86/100
# 2614/2614 [==============================] - 0s 177us/step - loss: 0.0838 - acc: 0.9977 - val_loss: 1.6210 - val_acc: 0.7122
#
# Epoch 00086: val_loss did not improve from 0.76259
# Epoch 87/100
# 2614/2614 [==============================] - 0s 178us/step - loss: 0.1048 - acc: 0.9901 - val_loss: 1.2917 - val_acc: 0.7202
#
# Epoch 00087: val_loss did not improve from 0.76259
# Epoch 88/100
# 2614/2614 [==============================] - 0s 182us/step - loss: 0.1716 - acc: 0.9644 - val_loss: 1.1318 - val_acc: 0.7259
#
# Epoch 00088: val_loss did not improve from 0.76259
# Epoch 89/100
# 2614/2614 [==============================] - 0s 177us/step - loss: 0.0831 - acc: 0.9981 - val_loss: 1.2863 - val_acc: 0.7305
#
# Epoch 00089: val_loss did not improve from 0.76259
# Epoch 90/100
# 2614/2614 [==============================] - 0s 177us/step - loss: 0.0865 - acc: 0.9954 - val_loss: 1.3518 - val_acc: 0.7328
#
# Epoch 00090: val_loss did not improve from 0.76259
# Epoch 91/100
# 2614/2614 [==============================] - 0s 186us/step - loss: 0.0874 - acc: 0.9958 - val_loss: 1.4216 - val_acc: 0.7225
#
# Epoch 00091: val_loss did not improve from 0.76259
# Epoch 92/100
# 2614/2614 [==============================] - 0s 156us/step - loss: 0.0806 - acc: 0.9977 - val_loss: 1.3529 - val_acc: 0.7167
#
# Epoch 00092: val_loss did not improve from 0.76259
# Epoch 93/100
# 2614/2614 [==============================] - 0s 155us/step - loss: 0.0731 - acc: 0.9996 - val_loss: 1.4804 - val_acc: 0.7282
#
# Epoch 00093: val_loss did not improve from 0.76259
# Epoch 94/100
# 2614/2614 [==============================] - 0s 155us/step - loss: 0.0724 - acc: 0.9989 - val_loss: 1.4901 - val_acc: 0.7248
#
# Epoch 00094: val_loss did not improve from 0.76259
# Epoch 95/100
# 2614/2614 [==============================] - 0s 154us/step - loss: 0.0703 - acc: 0.9996 - val_loss: 1.6232 - val_acc: 0.7190
#
# Epoch 00095: val_loss did not improve from 0.76259
# Epoch 96/100
# 2614/2614 [==============================] - 0s 154us/step - loss: 0.0688 - acc: 1.0000 - val_loss: 1.4891 - val_acc: 0.7305
#
# Epoch 00096: val_loss did not improve from 0.76259
# Epoch 97/100
# 2614/2614 [==============================] - 0s 155us/step - loss: 0.0663 - acc: 1.0000 - val_loss: 1.5184 - val_acc: 0.7248
#
# Epoch 00097: val_loss did not improve from 0.76259
# Epoch 98/100
# 2614/2614 [==============================] - 0s 165us/step - loss: 0.0679 - acc: 1.0000 - val_loss: 1.5651 - val_acc: 0.7110
#
# Epoch 00098: val_loss did not improve from 0.76259
# Epoch 99/100
# 2614/2614 [==============================] - 0s 167us/step - loss: 0.0668 - acc: 0.9996 - val_loss: 1.4573 - val_acc: 0.7294
#
# Epoch 00099: val_loss did not improve from 0.76259
# Epoch 100/100
# 2614/2614 [==============================] - 0s 176us/step - loss: 0.0641 - acc: 1.0000 - val_loss: 1.4885 - val_acc: 0.7397
#
# Epoch 00100: val_loss did not improve from 0.76259

# %%
# Import Model Test if not need to Train 
if not TRAIN :
    model = model_load ( model_bin_dir, Model_name)

# %%
# Display curves of loss and accuracy during training and save results 
plot_save_acc_loss(results_dir, history.history, Model_name)

# %%
# Import Model Test if not need to Train 

if Pre_model == "ResNet50":
        Model_name = "Model6_0_ResNet50"
else:
        Model_name = "Model6_0_VGG16"
model = model_load ( model_bin_dir, Model_name)
model.load_weights(model_bin_dir+"Best_weights"+Model_name+".hdf5")

# %%
#Evaluate your model  -> Evaluation number -> nº samples/ size batch times
#scores = model.evaluate(test_generator, verbose=1, steps = 31)
# Evaluates with numpy arrays
scores = model.evaluate(test_features, test_labels, verbose=1)

# %%
model.metrics_names

# %%
scores

# %%
# Res net50  loss = 0.52  acc=0.74
# VGG        Loss = 75    Accuracy of 77%

# %%
# Compute predictions
# This takes time !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
y_pred_keras = model.predict(test_features).ravel()        # y_pred probabilities
y_pred = y_pred_keras > 0.5                                # y_pred_class : if >0.5  = True => Malignant
#y_test = test_generator.classes                            # Ground truth
#class_labels = list(test_generator.class_indices.keys())   # Class labels
y_test = dftest.bm.astype('category').cat.codes
class_labels= dftest.bm.unique()

# %%
#Print Metrics + Confusion ROC AUC
confusion_ROC_AUC ( y_test, y_pred, y_pred_keras, class_labels, results_dir, Model_name )
